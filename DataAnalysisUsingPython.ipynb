# %%
import pandas as pd
import json


def load_json_to_df(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            data.append(json.loads(line))
    return pd.DataFrame(data)

# Paths to the JSON files in the Kaggle environment

business_path = '/kaggle/input/yelp-dataset/yelp_academic_dataset_business.json'
checkin_path = '/kaggle/input/yelp-dataset/yelp_academic_dataset_checkin.json'
review_path = '/kaggle/input/yelp-dataset/yelp_academic_dataset_review.json'
tip_path = '/kaggle/input/yelp-dataset/yelp_academic_dataset_tip.json'
user_path = '/kaggle/input/yelp-dataset/yelp_academic_dataset_user.json'

# Load the datasets
business_df = load_json_to_df(business_path)
checkin_df = load_json_to_df(checkin_path)
review_df = load_json_to_df(review_path)
tip_df = load_json_to_df(tip_path)
user_df = load_json_to_df(user_path)


checkin_df['date'] = checkin_df['date'].str.split(', ')
checkin_df = checkin_df.explode('date')


review_with_business = review_df.merge(business_df[['business_id', 'city']], on='business_id', how='left')


checkin_with_business = checkin_df.merge(business_df[['business_id', 'city']], on='business_id', how='left')


# Query 1: Select all businesses in the state of Illinois (IL)
business_in_il = business_df[business_df['state'] == 'IL']

# Query 2: Select all businesses with a star rating greater than 4
business_above_4_stars = business_df[business_df['stars'] > 4]

# Query 3: Select all 5-star businesses in Illinois (IL)
five_star_business_in_il = business_df[(business_df['stars'] == 5) & (business_df['state'] == 'IL')]

# Query 4: Select top 10 businesses in New Orleans by review count
top_business_in_new_orleans = business_df[business_df['city'] == 'New Orleans'].nlargest(10, 'review_count')

# Query 5: Select distinct categories of 5-star businesses in Illinois (IL)
distinct_categories_in_il = five_star_business_in_il['categories'].unique()

# Query 6: Select top 5 businesses in New Orleans with more than 100 reviews, ordered by stars descending
top_business_over_100_reviews = business_df[
    (business_df['city'] == 'New Orleans') & (business_df['review_count'] > 100)
].nlargest(5, 'stars')

# Query 7: Select top 5 categories in New Orleans with more than 4.5 stars
top_categories_over_45_stars = business_df[
    (business_df['city'] == 'New Orleans') & (business_df['stars'] > 4.5)
]['categories'].value_counts().head(5)

# Query 8: Select average review count per category in New Orleans
average_review_count_new_orleans = business_df[
    business_df['city'] == 'New Orleans'
].groupby('categories')['review_count'].mean().sort_values(ascending=False)

# Query 9: Select average star rating and number of reviews for businesses in New Orleans
avg_stars_and_reviews_new_orleans = review_with_business[
    review_with_business['city'] == 'New Orleans'
].groupby('business_id').agg(
    avg_stars=('stars', 'mean'),
    number_of_reviews=('review_id', 'count')
)

# Query 10: Select top 5 categories by total checkins in New Orleans
top_checkins_categories_new_orleans = checkin_with_business[
    checkin_with_business['city'] == 'New Orleans'
].groupby('business_id').size().reset_index(name='total_checkins').merge(
    business_df[['business_id', 'categories']], on='business_id', how='left'
).groupby('categories')['total_checkins'].sum().nlargest(5)


# Business in Illinois
print("# Query 1: Business in IL:")
print(business_in_il)
print("\n")  # Adding a newline for better separation in the output

# Businesses with a star rating greater than 4
print("# Query 2: Business above 4 stars:")
print(business_above_4_stars)
print("\n")

# Five-star businesses in Illinois
print("# Query 3: Five star business in IL:")
print(five_star_business_in_il)
print("\n")

# Top 10 businesses in New Orleans by review count
print("# Query 4: Top business in New Orleans:")
print(top_business_in_new_orleans)
print("\n")

# Distinct categories of 5-star businesses in Illinois
print("# Query 5: Distinct categories in IL:")
print(distinct_categories_in_il)
print("\n")

# Top 5 businesses in New Orleans with more than 100 reviews
print("# Query 6: Top business over 100 reviews in New Orleans:")
print(top_business_over_100_reviews)
print("\n")

# Top 5 categories in New Orleans with more than 4.5 stars
print("# Query 7: Top categories over 4.5 stars in New Orleans:")
print(top_categories_over_45_stars)
print("\n")

# Average review count per category in New Orleans
print("# Query 8: Average review count per category in New Orleans:")
print(average_review_count_new_orleans)
print("\n")

# Average star rating and number of reviews for businesses in New Orleans
print("# Query 9: Avg stars and number of reviews in New Orleans:")
print(avg_stars_and_reviews_new_orleans)
print("\n")

# Top 5 categories by total check-ins in New Orleans
print("# Query 10: Top check-ins categories in New Orleans:")
print(top_checkins_categories_new_orleans)
# Out:
# # Query 1: Business in IL:
#                    business_id                                 name  \
# 38      LcAozWCMLGjwRbokaJAKMg       Edwardsville Children's Museum
# 41      ljxNT9p0y7YMPx0fcNBGig  Tony's Restaurant & 3rd Street Cafe
# 48      bCBPXIVfVzBZBEpFu29dcg                      All In Shipping
# 86      sE6jSnvMts_MAn-b4OkMAw                       K-9 Groom Room
# 102     EuRGgOwJ0g1vTj2R04j37Q                          Crafty Crab
# ...                        ...                                  ...
# 150020  H9I0agL8A8r1eBh6p66o_Q                            Pizza Hut
# 150042  cdbEEL_0TLOPgdfsB3PUvA                               Subway
# 150110  eQ83iTisgPFzJ1YBO3p-IA                       Domino's Pizza
# 150155  yKgxtgSBkDeuBsfjQVV-jA                       Chinese Dragon
# 150344  mtGm22y5c2UHNXDFAjaPNw             Cyclery & Fitness Center
#
#                             address              city state postal_code  \
# 38                  722 Holyoake Rd      Edwardsville    IL       62025
# 41                     312 Piasa St             Alton    IL       62002
# 48      5343 Belleville Crossing St        Belleville    IL       62226
# 86                820 Industrial Dr              Troy    IL       62294
# 102                    51 Ludwig Dr  Fairview Heights    IL       62208
# ...                             ...               ...   ...         ...
# 150020           5913 N Illinois St  Fairview Heights    IL       62208
# 150042             413 Belt Line Rd      Collinsville    IL       62234
# 150110               4000 W Main St        Belleville    IL       62226
# 150155                510 S Main St          Smithton    IL       62285
# 150344                 2472 Troy Rd      Edwardsville    IL       62025
#
#          latitude  longitude  stars  review_count  is_open  \
# 38      38.804395 -89.949733    4.5            12        1
# 41      38.896563 -90.186203    3.0            94        1
# 48      38.517586 -90.021929    5.0             5        1
# 86      38.716244 -89.885830    4.0             5        1
# 102     38.601298 -89.989683    2.5            14        1
# ...           ...        ...    ...           ...      ...
# 150020  38.586224 -89.985703    2.5             8        1
# 150042  38.691322 -89.974966    2.5             9        1
# 150110  38.536365 -90.019293    2.0            22        1
# 150155  38.404248 -89.991511    4.5             5        1
# 150344  38.782351 -89.950558    4.0            24        1
#
#                                                attributes  \
# 38      {'GoodForKids': 'True', 'BusinessAcceptsCredit...
# 41      {'RestaurantsReservations': 'True', 'Restauran...
# 48                 {'BusinessAcceptsCreditCards': 'True'}
# 86                                                   None
# 102     {'BusinessParking': '{u'valet': False, u'garag...
# ...                                                   ...
# 150020  {'RestaurantsTakeOut': 'True', 'RestaurantsRes...
# 150042  {'BikeParking': 'True', 'NoiseLevel': 'u'avera...
# 150110  {'RestaurantsGoodForGroups': 'False', 'GoodFor...
# 150155  {'RestaurantsPriceRange2': '1', 'RestaurantsTa...
# 150344  {'BusinessParking': '{'garage': False, 'street...
#
#                                                categories  \
# 38      Museums, Kids Activities, Arts & Entertainment...
# 41      Restaurants, Specialty Food, Steakhouses, Food...
# 48                       Shipping Centers, Local Services
# 86          Pet Groomers, Pet Sitting, Pets, Pet Services
# 102                                  Seafood, Restaurants
# ...                                                   ...
# 150020  Pizza, Restaurants, Fast Food, Italian, Chicke...
# 150042                 Restaurants, Sandwiches, Fast Food
# 150110      Chicken Wings, Pizza, Sandwiches, Restaurants
# 150155                               Chinese, Restaurants
# 150344  Fitness/Exercise Equipment, Eyewear & Optician...
#
#                                                     hours
# 38      {'Monday': '10:0-15:0', 'Tuesday': '9:30-14:0'...
# 41      {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:30',...
# 48                                                   None
# 86      {'Monday': '8:0-16:0', 'Tuesday': '8:0-16:0', ...
# 102     {'Monday': '12:0-22:0', 'Tuesday': '12:0-22:0'...
# ...                                                   ...
# 150020  {'Monday': '10:30-22:0', 'Tuesday': '10:30-22:...
# 150042  {'Monday': '10:30-19:30', 'Tuesday': '10:30-19...
# 150110  {'Monday': '10:0-1:0', 'Tuesday': '10:0-1:0', ...
# 150155  {'Monday': '0:0-0:0', 'Tuesday': '10:30-21:0',...
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
#
# [2145 rows x 14 columns]
#
#
# # Query 2: Business above 4 stars:
#                    business_id                           name  \
# 0       Pns2l4eNsfO8kk83dixA6A       Abby Rappoport, LAC, CMQ
# 4       mWMc6_wTdE0EUBKIGXDVfA       Perkiomen Valley Brewery
# 13      jaxMSoInw8Poo3XeMJt8lQ                   Adams Dental
# 14      0bPLkL0QhhPO5kt1_EXmNQ           Zio's Italian Market
# 16      rBmpy_Y1UbBx8ggHlyb7hA       Arizona Truck Outfitters
# ...                        ...                            ...
# 150334  LJ4GjQ1HL6kqvIPpNUNNaQ       Shanti Yoga and Ayurveda
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 150340  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
# 150345  jV_XOycEzSlTx-65W906pg                        Sic Ink
#
#                        address           city state postal_code   latitude  \
# 0       1616 Chapala St, Ste 2  Santa Barbara    CA       93101  34.426679
# 4                101 Walnut St     Green Lane    PA       18054  40.338183
# 13           15 N Missouri Ave     Clearwater    FL       33755  27.966235
# 14               2575 E Bay Dr          Largo    FL       33771  27.916116
# 16             625 N Stone Ave         Tucson    AZ       85705  32.229872
# ...                        ...            ...   ...         ...        ...
# 150334      1638 Pine St, Fl 1   Philadelphia    PA       19103  39.945966
# 150336           1108 S 9th St   Philadelphia    PA       19147  39.935982
# 150339         4405 Pennell Rd          Aston    DE       19014  39.856185
# 150340   2470 Guardian Road NW       Edmonton    AB     T5T 1K8  53.509649
# 150345   238 Apollo Beach Blvd   Apollo beach    FL       33572  27.771002
#
#          longitude  stars  review_count  is_open  \
# 0      -119.711197    5.0             7        0
# 4       -75.471659    4.5            13        1
# 13      -82.787412    5.0            10        1
# 14      -82.760461    4.5           100        0
# 16     -110.972342    4.5            10        1
# ...            ...    ...           ...      ...
# 150334  -75.169666    4.5            39        1
# 150336  -75.158665    4.5            35        1
# 150339  -75.427725    4.5            14        1
# 150340 -113.675999    4.5            18        0
# 150345  -82.394910    4.5             9        1
#
#                                                attributes  \
# 0                           {'ByAppointmentOnly': 'True'}
# 4       {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 13                          {'ByAppointmentOnly': 'True'}
# 14      {'OutdoorSeating': 'False', 'RestaurantsGoodFo...
# 16      {'DriveThru': 'False', 'BusinessAcceptsCreditC...
# ...                                                   ...
# 150334  {'ByAppointmentOnly': 'True', 'GoodForKids': '...
# 150336  {'WheelchairAccessible': 'False', 'Restaurants...
# 150339  {'RestaurantsDelivery': 'False', 'BusinessAcce...
# 150340  {'Ambience': '{'touristy': False, 'hipster': F...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                                                categories  \
# 0       Doctors, Traditional Chinese Medicine, Naturop...
# 4                               Brewpubs, Breweries, Food
# 13      General Dentistry, Dentists, Health & Medical,...
# 14            Food, Delis, Italian, Bakeries, Restaurants
# 16      Automotive, Auto Parts & Supplies, Auto Custom...
# ...                                                   ...
# 150334  Health & Medical, Yoga, Shopping, Naturopathic...
# 150336                               Restaurants, Mexican
# 150339  Restaurants, Comfort Food, Food, Food Trucks, ...
# 150340                        Middle Eastern, Restaurants
# 150345  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
#                                                     hours
# 0                                                    None
# 4       {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...
# 13      {'Monday': '7:30-15:30', 'Tuesday': '7:30-15:3...
# 14      {'Monday': '10:0-18:0', 'Tuesday': '10:0-20:0'...
# 16      {'Monday': '0:0-0:0', 'Tuesday': '8:0-17:0', '...
# ...                                                   ...
# 150334  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 150336  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 150339  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150340  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [43488 rows x 14 columns]
#
#
# # Query 3: Five star business in IL:
#                    business_id                      name  \
# 48      bCBPXIVfVzBZBEpFu29dcg           All In Shipping
# 1805    MOBvgVwvZMV8hyngcr7hfw  Shiloh Veterinary Clinic
# 2071    RpWoiNTe8mCVrcMoCDa86w      My Vintage Addiction
# 2774    iipnazeY9eoANJ37l5fKwA          Post Pack & Ship
# 3923    f_6cI4MdPem_48WgD1Ofcw   Clara B's Kitchen Table
# ...                        ...                       ...
# 146997  ARpMrJ6ugUQTV6YI57-kuQ        Backtothe80sarcade
# 147281  9QYR6wLNooEHcpUEqK6XWA               Barber Shop
# 147934  BiiFY58y7IHJO94TWUy_Rw        Vern's Auto Repair
# 149685  2-SB-GoaYiCEUTBfCTm3qA       Bluestem Distillery
# 149857  kxs_y4UlQl3p1ByNPB4H7A  Lucinda's Grill and Cafe
#
#                             address          city state postal_code  \
# 48      5343 Belleville Crossing St    Belleville    IL       62226
# 1805      3690 Green Mount Crossing        Shiloh    IL       62269
# 2071                  119 E Main St    Belleville    IL       62220
# 2774                   637 W Hwy 50      O'Fallon    IL       62269
# 3923                                      Swansea    IL       62220
# ...                             ...           ...   ...         ...
# 146997   8719 Hanover Industrial Dr      Columbia    IL       62236
# 147281                 113 Plaza Ct  Edwardsville    IL       62025
# 147934              245 N Center St  Collinsville    IL       62234
# 149685         5313 State Route 140      Bethalto    IL       62010
# 149857                 925 S Belt W    Belleville    IL       62220
#
#          latitude  longitude  stars  review_count  is_open  \
# 48      38.517586 -90.021929    5.0             5        1
# 1805    38.556274 -89.928631    5.0            10        1
# 2071    38.513847 -89.981993    5.0             6        0
# 2774    38.588157 -89.923034    5.0             9        0
# 3923    38.474978 -89.990876    5.0             5        1
# ...           ...        ...    ...           ...      ...
# 146997  38.391263 -90.172297    5.0             5        1
# 147281  38.811916 -89.955788    5.0             6        1
# 147934  38.672712 -89.987612    5.0             5        1
# 149685  38.898779 -90.005593    5.0             5        1
# 149857  38.509142 -90.001790    5.0             5        0
#
#                                                attributes  \
# 48                 {'BusinessAcceptsCreditCards': 'True'}
# 1805                                                 None
# 2071    {'ByAppointmentOnly': 'False', 'RestaurantsPri...
# 2774                                                 None
# 3923                          {'OutdoorSeating': 'False'}
# ...                                                   ...
# 146997                                               None
# 147281  {'BusinessParking': '{'garage': False, 'street...
# 147934             {'BusinessAcceptsCreditCards': 'True'}
# 149685  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 149857  {'BusinessAcceptsCreditCards': 'True', 'Restau...
#
#                                                categories  \
# 48                       Shipping Centers, Local Services
# 1805                                  Veterinarians, Pets
# 2071                                   Antiques, Shopping
# 2774    Packing Services, Shipping Centers, Local Serv...
# 3923    Restaurants, Southern, Food Trucks, Food, Brea...
# ...                                                   ...
# 146997                      Arcades, Arts & Entertainment
# 147281                Hair Salons, Beauty & Spas, Barbers
# 147934  Oil Change Stations, Auto Repair, Tires, Autom...
# 149685  Distilleries, Medical Supplies, Food, Shopping...
# 149857                                 Cafes, Restaurants
#
#                                                     hours
# 48                                                   None
# 1805    {'Monday': '8:0-18:0', 'Tuesday': '7:0-18:0', ...
# 2071    {'Tuesday': '10:0-17:0', 'Wednesday': '10:0-17...
# 2774                                                 None
# 3923                                                 None
# ...                                                   ...
# 146997  {'Thursday': '17:0-22:0', 'Friday': '17:0-22:0...
# 147281  {'Tuesday': '8:30-17:0', 'Wednesday': '8:30-17...
# 147934  {'Monday': '8:0-17:30', 'Tuesday': '8:0-17:30'...
# 149685  {'Monday': '0:0-0:0', 'Thursday': '16:0-20:0',...
# 149857  {'Monday': '11:0-19:0', 'Tuesday': '11:0-19:0'...
#
# [160 rows x 14 columns]
#
#
# # Query 4: Top business in New Orleans:
#                    business_id                             name  \
# 113731  _ab50qdWOk0DdB6XOrBitw                Acme Oyster House
# 112552  ac1AeYqs8Z4_e2X5M3if2A                     Oceana Grill
# 147081  oBNrLz4EDhiscSlbOl8uAw       Ruby Slipper - New Orleans
# 100024  iSRTaT9WngzB8JJ2YKJUig              Mother's Restaurant
# 31033   VQcCL9PiNL_wkGf-uF3fjg                      Royal House
# 31332   _C7QiQQc47AOEv4PE3Kong               Commander's Palace
# 4497    GBTPC53ZrG1ZBY3DT8Mbcw                             Luke
# 97331   6a4gLLFSgr-Q6CZXDLzBGQ                           Cochon
# 64541   VaO-VW3e1kARkU9bP1E7Fw  Felix's Restaurant & Oyster Bar
# 42331   qb28j-FNX1_6xm7u372TZA                       Gumbo Shop
#
#                       address         city state postal_code   latitude  \
# 113731       724 Iberville St  New Orleans    LA       70130  29.954273
# 112552           739 Conti St  New Orleans    LA       70130  29.956231
# 147081        200 Magazine St  New Orleans    LA       70130  29.951025
# 100024         401 Poydras St  New Orleans    LA       70130  29.949057
# 31033            441 Royal St  New Orleans    LA       70130  29.956473
# 31332     1403 Washington Ave  New Orleans    LA       70130  29.928735
# 4497    333 Saint Charles Ave  New Orleans    LA       70130  29.950742
# 97331    930 Tchoupitoulas St  New Orleans    LA       70130  29.942280
# 64541        739 Iberville St  New Orleans    LA       70130  29.954680
# 42331         630 St Peter St  New Orleans    LA       70116  29.957709
#
#         longitude  stars  review_count  is_open  \
# 113731 -90.068965    4.0          7568        1
# 112552 -90.067563    4.0          7400        1
# 147081 -90.067394    4.5          5193        1
# 100024 -90.067049    3.5          5185        1
# 31033  -90.066386    4.0          5070        1
# 31332  -90.084196    4.5          4876        1
# 4497   -90.070416    4.0          4554        1
# 97331  -90.067268    4.0          4421        1
# 64541  -90.068945    4.0          3966        1
# 42331  -90.064537    4.0          3902        1
#
#                                                attributes  \
# 113731  {'RestaurantsTakeOut': 'True', 'Alcohol': ''fu...
# 112552  {'RestaurantsGoodForGroups': 'True', 'Restaura...
# 147081  {'NoiseLevel': ''loud'', 'Caters': 'False', 'B...
# 100024  {'RestaurantsGoodForGroups': 'True', 'BYOBCork...
# 31033   {'WiFi': 'u'free'', 'Caters': 'False', 'Outdoo...
# 31332   {'RestaurantsGoodForGroups': 'True', 'OutdoorS...
# 4497    {'RestaurantsReservations': 'True', 'Restauran...
# 97331   {'BikeParking': 'True', 'BusinessParking': '{'...
# 64541   {'GoodForKids': 'True', 'HasTV': 'True', 'Nois...
# 42331   {'GoodForKids': 'True', 'RestaurantsAttire': '...
#
#                                                categories  \
# 113731  Live/Raw Food, Seafood, Restaurants, Cajun/Creole
# 112552  Restaurants, Seafood, Cajun/Creole, Breakfast ...
# 147081  Restaurants, American (Traditional), American ...
# 100024  Cajun/Creole, Restaurants, Event Planning & Se...
# 31033   American (New), Restaurants, Sandwiches, Seafo...
# 31332   French, Restaurants, Cocktail Bars, Nightlife,...
# 4497    German, Restaurants, Seafood, Cocktail Bars, F...
# 97331                  Cajun/Creole, Seafood, Restaurants
# 64541      Restaurants, Sandwiches, Seafood, Cajun/Creole
# 42331                  Cajun/Creole, Seafood, Restaurants
#
#                                                     hours
# 113731  {'Monday': '11:0-22:0', 'Thursday': '11:0-22:0...
# 112552  {'Monday': '8:0-1:0', 'Tuesday': '8:0-1:0', 'W...
# 147081  {'Monday': '0:0-0:0', 'Tuesday': '7:30-14:0', ...
# 100024  {'Monday': '0:0-0:0', 'Tuesday': '7:0-17:0', '...
# 31033   {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 31332   {'Monday': '0:0-0:0', 'Tuesday': '18:0-21:30',...
# 4497    {'Monday': '7:0-21:0', 'Tuesday': '7:0-21:0', ...
# 97331   {'Tuesday': '11:0-21:0', 'Wednesday': '11:0-21...
# 64541   {'Monday': '0:0-0:0', 'Tuesday': '11:0-21:0', ...
# 42331   {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
#
#
# # Query 5: Distinct categories in IL:
# ['Shipping Centers, Local Services' 'Veterinarians, Pets'
#  'Antiques, Shopping'
#  'Packing Services, Shipping Centers, Local Services, Home Services'
#  'Restaurants, Southern, Food Trucks, Food, Breakfast & Brunch, Desserts'
#  'Event Planning & Services, Photographers' 'Axe Throwing, Active Life'
#  'Ice Cream & Frozen Yogurt, Food'
#  'Acupuncture, Health & Medical, Physical Therapy, Weight Loss Centers, Massage Therapy, Chiropractors'
#  'Beer, Wine & Spirits, Bars, Wineries, Food, Nightlife, Arts & Entertainment, Wine Bars, Wine Tasting Room'
#  'Optometrists, Health & Medical'
#  'Veterinarians, Pet Sitting, Pets, Pet Services'
#  'Local Services, Carpet Cleaning' 'Tanning, Spray Tanning, Beauty & Spas'
#  'Automotive, Auto Parts & Supplies, Transmission Repair, Auto Repair'
#  'Kitchen & Bath, Appliances & Repair, Local Services, Appliances, Home & Garden, Shopping'
#  'Keys & Locksmiths, Automotive, Local Services, Auto Repair, Home Services'
#  'Contractors, Electricians, Heating & Air Conditioning/HVAC, Home Services'
#  'Local Services, Laundry Services, Dry Cleaning & Laundry'
#  'Restaurants, Bakeries, Food'
#  'Public Services & Government, Venues & Event Spaces, Bed & Breakfast, Hotels & Travel, Hotels, Event Planning & Services, Landmarks & Historical Buildings, Arts & Entertainment, Museums, Wedding Chapels'
#  'Educational Services, Elementary Schools, Recreation Centers, Education, Specialty Schools, Local Services, Local Flavor, Community Service/Non-Profit, Active Life, Parks'
#  'Pizza, Sandwiches, Donuts, Restaurants, Food, Bakeries'
#  'Soup, Restaurants, Food, Tea Rooms, Breakfast & Brunch, Sandwiches'
#  'Bridal, Shopping' 'Distilleries, Food'
#  'Food, Breakfast & Brunch, Sandwiches, Coffee & Tea, Specialty Food, Restaurants'
#  'Plumbing, Home Services, Air Duct Cleaning, Pest Control, Home & Garden, Professional Services, Advertising, Metal Fabricators, Kitchen & Bath, Shopping, Heating & Air Conditioning/HVAC, Contractors, Local Services'
#  'Breweries, Food, Shopping, Brewing Supplies'
#  'Hair Salons, Beauty & Spas' 'Restaurants'
#  'Flowers & Gifts, Party & Event Planning, Gift Shops, Shopping, Wedding Planning, Event Planning & Services, Florists, Floral Designers'
#  'Pumpkin Patches, Food, Shopping, Farmers Market, Home & Garden'
#  'Southern, American (Traditional), Restaurants, Soul Food'
#  'Health & Medical, Chiropractors'
#  'Coffee & Tea, Ice Cream & Frozen Yogurt, Food'
#  'Beer, Wine & Spirits, Food'
#  'Day Spas, Nail Salons, Massage, Skin Care, Chiropractors, Massage Therapy, Health & Medical, Reflexology, Beauty & Spas, Waxing, Hair Removal'
#  'Beauty & Spas, Barbers' 'Active Life, Fitness & Instruction, Yoga'
#  'Books, Mags, Music & Video, Comic Books, Shopping'
#  'Auto Parts & Supplies, Car Dealers, Automotive, Auto Repair'
#  'Caribbean, Cuban, American (New), Latin American, Restaurants'
#  'Coffee & Tea, Food'
#  'Used, Vintage & Consignment, Home Decor, Home & Garden, Shopping, Fashion'
#  'Medical Centers, Pediatric Dentists, Dentists, General Dentistry, Health & Medical, Cosmetic Dentists, Endodontists'
#  "Fashion, Women's Clothing, Department Stores, Home & Garden, Shopping, Home Decor"
#  'Automotive, Auto Repair, Tires'
#  'Pets, Dog Walkers, Pet Services, Pet Boarding, Pet Sitting'
#  'General Dentistry, Health & Medical, Dentists'
#  'Local Services, Clock Repair, Shopping, Watch Repair, Watches'
#  'Food, Burgers, Restaurants, Ice Cream & Frozen Yogurt'
#  'Arts & Entertainment, Arcades, Amusement Parks, Active Life'
#  'Butcher, Meat Shops, Specialty Food, Food'
#  'Mattresses, Shopping, Furniture Stores, Home & Garden, Home Decor'
#  'Tires, Automotive'
#  'Hotels & Travel, Event Planning & Services, Wedding Chapels, Bed & Breakfast, Guest Houses, Vacation Rentals, Hotels'
#  'Books, Mags, Music & Video, Shopping, Comic Books'
#  'Health & Medical, Ophthalmologists, Doctors, Shopping, Optometrists, Eyewear & Opticians'
#  'Barbers, Beauty & Spas'
#  'IT Services & Computer Repair, Mobile Phone Repair, Local Services, Professional Services, Electronics Repair'
#  'Shopping, Watches, Jewelry'
#  'Public Transportation, Transportation, Hotels & Travel'
#  'Shopping, Arts & Crafts'
#  'Pediatric Dentists, Health & Medical, Dentists'
#  'Real Estate, Home Inspectors, Home Services'
#  'Toy Stores, Hobby Shops, Shopping'
#  "Used, Vintage & Consignment, Shopping, Home Decor, Home & Garden, Fashion, Women's Clothing"
#  'Cupcakes, Food, Desserts, Bakeries' 'Tex-Mex, Restaurants, Mexican'
#  'Bakeries, Patisserie/Cake Shop, Desserts, Food'
#  'Interval Training Gyms, Trainers, Active Life, Fitness & Instruction, Gyms'
#  'Beauty & Spas, Hair Salons'
#  'Pet Services, Hospitals, Health & Medical, Pets, Veterinarians'
#  'Pizza, Italian, Restaurants' 'Pets, Veterinarians'
#  'Gas Stations, Automotive, Auto Detailing'
#  'Coffee & Tea, Herbs & Spices, Specialty Food, Food' 'Cafes, Restaurants'
#  'Damage Restoration, Home Services, Tree Services, Crane Services, Local Services'
#  'Airsoft, Sporting Goods, Paintball, Skate Shops, Shopping, Active Life'
#  'Body Shops, Automotive'
#  'Office Cleaning, Home & Garden, Home Services, Contractors, Furniture Stores, Carpet Cleaning, Home Cleaning, Shopping, Local Services, Professional Services'
#  'Auto Detailing, Towing, Automotive, Body Shops'
#  'Real Estate Agents, Home Services, Real Estate, Real Estate Services'
#  'Barbers, Hair Salons, Beauty & Spas'
#  'Pet Training, Dog Walkers, Pet Groomers, Pets, Pet Sitting, Pet Services'
#  'Local Services, Notaries, Public Services & Government, Departments of Motor Vehicles, Registration Services, Automotive'
#  'Pubs, Bars, Nightlife, Beer Bar, Breweries, Food, Brewpubs'
#  'Dog Walkers, Pets, Pet Sitting, Pet Boarding, Pet Services, Pet Training'
#  'Laundry Services, Dry Cleaning & Laundry, Sewing & Alterations, Local Services'
#  'DUI Law, Professional Services, Lawyers, Personal Injury Law, Divorce & Family Law, Criminal Defense Law'
#  'Furniture Stores, Shopping, Home & Garden' 'Automotive, Tires'
#  'Shopping, Nurseries & Gardening, Home & Garden'
#  'Pet Sitting, Pet Services, Pets'
#  'Real Estate, Home Services, Real Estate Services, Home Inspectors'
#  'Massage Therapy, Massage, Skin Care, Health & Medical, Beauty & Spas, Hair Removal'
#  'British, Tea Rooms, Event Planning & Services, Coffee & Tea, Venues & Event Spaces, Food, Cafes, Restaurants, Bakeries'
#  'Restaurants, Chinese' 'Desserts, Bakeries, Food, Cupcakes'
#  'Plumbing, Home Services, Contractors'
#  'Cocktail Bars, Nightlife, Wine Bars, Bars'
#  'Auto Parts & Supplies, Transmission Repair, Automotive, Oil Change Stations, Auto Repair'
#  'Local Services, Automotive, Notaries, Registration Services'
#  'Custom Cakes, Desserts, Ice Cream & Frozen Yogurt, Food'
#  'Bike Repair/Maintenance, Active Life, Bikes, Bike Rentals, Sporting Goods, Local Services, Shopping'
#  'Mexican, Restaurants'
#  'Tree Services, Snow Removal, Home Services, Firewood, Local Services'
#  'Supernatural Readings, Arts & Entertainment, Local Services, Jewelry, Shopping, Education'
#  'Summer Camps, Education, Specialty Schools, Active Life, Local Services, Preschools, Elementary Schools, Child Care & Day Care'
#  'Shopping, Eyewear & Opticians, Health & Medical, Optometrists, Medical Centers'
#  'Massage, Beauty & Spas, Health & Medical, Chiropractors'
#  'Fences & Gates, Decks & Railing, Home Services'
#  'Saunas, Reflexology, Massage, Health & Medical, Beauty & Spas, Massage Therapy'
#  'Auto Parts & Supplies, Automotive' 'Automotive, Auto Repair'
#  'Nightlife, Wine Bars, Bars'
#  'Private Schools, Middle Schools & High Schools, Elementary Schools, Education'
#  'Specialty Food, Fruits & Veggies, Food'
#  'Bakeries, Coffee & Tea, Food, Desserts, Cupcakes'
#  "Women's Clothing, Fashion, Shopping"
#  'Event Planning & Services, Bars, American (Traditional), Venues & Event Spaces, Restaurants, Nightlife, Barbeque'
#  'Active Life, Escape Games' 'Sandwiches, Restaurants, Burgers'
#  'Jewelry, Shopping' 'Nightlife, Bars, Wine Bars'
#  'Nightlife, Bars, Cocktail Bars'
#  'Shopping, Sports Wear, Fashion, Local Services, Screen Printing/T-Shirt Printing, Sporting Goods'
#  'Restaurants, Mexican, Caterers, Event Planning & Services'
#  'Historical Tours, Professional Services, Tours, Hotels & Travel, Restaurants'
#  'Food, Restaurants, Butcher, Delis'
#  'Massage Therapy, Massage, Beauty & Spas, Health & Medical, Ayurveda'
#  'Food, Food Trucks'
#  'Escape Games, Event Planning & Services, Team Building Activities, Active Life'
#  'Food, Beer, Wine & Spirits' 'Tires, Automotive, Auto Repair'
#  'Local Flavor'
#  'Auto Glass Services, Glass & Mirrors, Automotive, Home Services, Windows Installation'
#  'Bars, Nightlife' 'Korean, Restaurants, Desserts, Food, Chicken Wings'
#  'Water Heater Installation/Repair, Contractors, Plumbing, Home Services'
#  'IT Services & Computer Repair, Local Services, Computers, Mobile Phone Repair, Electronics Repair, Data Recovery, Shopping'
#  'Hair Stylists, Hair Salons, Beauty & Spas, Day Spas'
#  'General Dentistry, Endodontists, Cosmetic Dentists, Health & Medical, Dentists'
#  'Coffee & Tea, Food, Coffee Roasteries' 'Arcades, Arts & Entertainment'
#  'Hair Salons, Beauty & Spas, Barbers'
#  'Oil Change Stations, Auto Repair, Tires, Automotive'
#  'Distilleries, Medical Supplies, Food, Shopping, Hotels & Travel, Tours']
#
#
# # Query 6: Top business over 100 reviews in New Orleans:
#                   business_id                            name  \
# 9508   0yGH62WGQy_W3JoR6L5Kew                   Ice Cream 504
# 25015  zxIF-bnaJ-eKIsznB7yu7A              Free Tours By Foot
# 25739  G-pGCyWQuNOywHdkKRcnpQ            Crescent City Cooks!
# 36811  3NObha3nErUqtucmcnUP5A  Buzz Nola Bike Tours & Rentals
# 44894  TDEV16C4GhK5wyhL-5V7ww         Flambeaux Bicycle Tours
#
#                 address         city state postal_code   latitude  longitude  \
# 9508       2511 Jena St  New Orleans    LA       70115  29.935437 -90.104024
# 25015    2613 Laurel St  New Orleans    LA       70130  29.925353 -90.079988
# 25739   201 Chartres St  New Orleans    LA       70130  29.953580 -90.067390
# 36811   214 Magazine St  New Orleans    LA       70130  29.950773 -90.067341
# 44894  626 N Rampart St  New Orleans    LA       70112  29.960026 -90.068536
#
#        stars  review_count  is_open  \
# 9508     5.0           139        1
# 25015    5.0           769        1
# 25739    5.0           109        0
# 36811    5.0           222        1
# 44894    5.0           167        1
#
#                                               attributes  \
# 9508   {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 25015                                  {'WiFi': 'u'no''}
# 25739  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# 36811  {'BusinessAcceptsCreditCards': 'True', 'BikePa...
# 44894  {'BikeParking': 'True', 'GoodForKids': 'True',...
#
#                                               categories  \
# 9508                     Ice Cream & Frozen Yogurt, Food
# 25015              Hotels & Travel, Walking Tours, Tours
# 25739  Education, Specialty Schools, Kitchen & Bath, ...
# 36811  Tours, Hotels & Travel, Bike tours, Active Lif...
# 44894  Bike Rentals, Local Flavor, Tours, Historical ...
#
#                                                    hours
# 9508   {'Monday': '14:0-20:30', 'Tuesday': '14:0-20:3...
# 25015  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 25739  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...
# 36811  {'Monday': '9:30-16:30', 'Tuesday': '9:30-16:3...
# 44894  {'Monday': '0:0-0:0', 'Tuesday': '9:0-17:0', '...
#
#
# # Query 7: Top categories over 4.5 stars in New Orleans:
# categories
# Beauty & Spas, Hair Salons          6
# Hotels & Travel, Bed & Breakfast    5
# Hotels & Travel, Tours              4
# Hair Salons, Beauty & Spas          4
# Local Flavor                        4
# Name: count, dtype: int64
#
#
# # Query 8: Average review count per category in New Orleans:
# categories
# Live/Raw Food, Seafood, Restaurants, Cajun/Creole                                                                                                                         7568.0
# Restaurants, Seafood, Cajun/Creole, Breakfast & Brunch                                                                                                                    7400.0
# Restaurants, American (Traditional), American (New), Cafes, Breakfast & Brunch                                                                                            5193.0
# Cajun/Creole, Restaurants, Event Planning & Services, Southern, Specialty Food, Soul Food, Food, Ethnic Food, American (New), Caterers, Breakfast & Brunch, Sandwiches    5185.0
# American (New), Restaurants, Sandwiches, Seafood, Cajun/Creole                                                                                                            5070.0
#                                                                                                                                                                            ...
# Electricians, Contractors, Lighting Fixtures & Equipment, Home Services                                                                                                      5.0
# Specialty Food, Seafood Markets, Restaurants, Cajun/Creole, Food                                                                                                             5.0
# Educational Services, Special Education, Speech Therapists, Private Tutors, Education, Health & Medical                                                                      5.0
# Education, Elementary Schools, Preschools                                                                                                                                    5.0
# Professional Services, Active Life, Boat Repair, Boating, Self Storage, Local Services                                                                                       5.0
# Name: review_count, Length: 4718, dtype: float64
#
#
# # Query 9: Avg stars and number of reviews in New Orleans:
#                         avg_stars  number_of_reviews
# business_id
# --S43ruInmIsGrnnkmavRw   3.354839                 93
# --x_BmZbxzK_nx_GHBaRVw   4.739130                 23
# --zb12mw2YK-7j6UaHzm8w   4.583333                 12
# -0__F9fnKt8uioCKztF5Ww   3.878788                 66
# -0ltw8--HLuulPyOSspqAQ   3.181818                 11
# ...                           ...                ...
# zyRXfBnoE1JZVN4SE7OaaA   3.078431                 51
# zynDyrQvFZfbf5m4_Usl5g   1.875000                  8
# zyrhpLocbo60EbS57jBTLw   3.714286                 28
# zzbZtgPYZS8sTIWQH6DwEw   2.816092                 87
# zznZqH9CiAznbkV6fXyHWA   4.916667                 12
#
# [6209 rows x 2 columns]
#
#
# # Query 10: Top check-ins categories in New Orleans:
# categories
# Flowers & Gifts, Gift Shops, Cafes, Restaurants, Coffee & Tea, Donuts, Food, Souvenir Shops, Shopping    40109
# American (New), Restaurants, Sandwiches, Seafood, Cajun/Creole                                           28927
# Restaurants, Seafood, Cajun/Creole, Breakfast & Brunch                                                   21542
# Cajun/Creole, Seafood, Restaurants                                                                       18423
# Live/Raw Food, Seafood, Restaurants, Cajun/Creole                                                        15205
# Name: total_checkins, dtype: int64
